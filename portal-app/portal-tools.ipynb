# %% [markdown]
# # Portal grades and transcript, as agent tools
#
# The `guc_portal` package reads your transcript and your grades. Here we wrap it
# as **LangChain tools** and let an agent answer questions like "what was my GPA in
# 2024-2025?" or "how did I do in Discrete Math last winter?".
#
# The tools we build:
#
# - `list_my_terms` : which terms do I have grades for
# - `list_courses_in_term` : which courses were in a term
# - `get_my_grades` : the detailed marks for one course
# - `list_transcript_years` : which academic years the transcript has
# - `get_my_transcript` : the courses, grades, and GPA for one year
#
# One warning: the portal is old, slow, and rate-limited. It answers about once a
# minute and errors if you rush it. The tools cache their results, and the package
# waits and retries on its own, but be patient in class.

# %% [markdown]
# ## 1. Log in

# %%
import os, getpass
from dotenv import load_dotenv

load_dotenv()  # GUC_USERNAME / GUC_PASSWORD from .env, if present
if not os.environ.get("GUC_USERNAME"):
    os.environ["GUC_USERNAME"] = input("GUC username: ")
if not os.environ.get("GUC_PASSWORD"):
    os.environ["GUC_PASSWORD"] = getpass.getpass("GUC password: ")

from guc_portal import GucPortal

portal = GucPortal()   # site defaults to "guc" (set GUC_SITE=giu to switch)
print("logged in to the portal")

# %% [markdown]
# ## 2. The tools
#
# Each tool wraps one package call and returns plain data. We keep a small cache so
# repeated questions do not hit the slow portal twice. Notice the grade and year
# tools take names/labels ("Winter 2024", "2024-2025"), not the portal's numeric
# ids, because that is what the model will say.

# %%
from langchain.tools import tool

_cache = {}


def _seasons():
    if "seasons" not in _cache:
        _cache["seasons"] = portal.available_seasons()  # [(value, label), ...]
    return _cache["seasons"]


def _years():
    if "years" not in _cache:
        _cache["years"] = portal.available_years()      # [(value, label), ...]
    return _cache["years"]


@tool
def list_my_terms() -> list[str]:
    """List the terms the student has grades for, e.g. 'Winter 2024'."""
    return [label for _v, label in _seasons()]


@tool
def list_courses_in_term(term: str) -> list[str]:
    """List the courses taught in a past term, e.g. 'Winter 2024'.
    Use this to find a course's exact name before asking for its grades."""
    value = next((v for v, label in _seasons() if term.lower() in label.lower()), None)
    if not value:
        return [f"no term matches {term!r}"]
    return [label for _v, label in portal.list_previous_courses(value)]


@tool
def get_my_grades(term: str, course: str) -> dict:
    """Detailed marks for one course in one term: each quiz/assignment (earned / max)
    plus the percentage of every course that term.
    `term` like 'Winter 2024', `course` like 'Discrete Math' or 'MATH501'."""
    key = ("grades", term.lower(), course.lower())
    if key not in _cache:
        g = portal.get_grades_by_name(term, course)
        _cache[key] = {
            "course": g.course,
            "term": g.season,
            "items": [{"what": i.assessment, "grade": i.grade} for i in g.items],
            "course_percentages": g.percentages,
        }
    return _cache[key]


@tool
def list_transcript_years() -> list[str]:
    """List the academic years on the transcript, e.g. '2024-2025'."""
    return [label for _v, label in _years()]


@tool
def get_my_transcript(year: str) -> dict:
    """The transcript for one academic year: each course with its letter grade,
    and the cumulative GPA. `year` is a label like '2024-2025'."""
    value = next((v for v, label in _years() if year in label), None)
    if not value:
        return {"error": f"no year matches {year!r}; options: {[l for _v, l in _years()]}"}
    key = ("tx", value)
    if key not in _cache:
        t = portal.get_transcript_year(value)
        _cache[key] = {
            "year": year,
            "cumulative_gpa": t.cumulative_gpa,
            "courses": [
                {"course": r.course, "grade": r.grade, "semester": r.semester} for r in t.rows
            ],
        }
    return _cache[key]

# %% [markdown]
# ## 3. Give the tools to an agent

# %%
from langchain.agents import create_agent
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage

model = ChatAnthropic(model="claude-haiku-4-5", temperature=0)

agent = create_agent(
    model=model,
    tools=[list_my_terms, list_courses_in_term, get_my_grades,
           list_transcript_years, get_my_transcript],
    system_prompt=(
        "You help a GUC student with their grades and transcript. Use the tools. "
        "The portal is slow, so call each tool as few times as you can, and reuse "
        "what you already fetched."
    ),
)


def ask(question):
    return agent.invoke({"messages": [HumanMessage(question)]})["messages"][-1].content


# Grades question (uses get_my_grades):
print(ask("How did I do in Discrete Math in Winter 2024? Which quiz was weakest?"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 24
#      20     return agent.invoke({"messages": [HumanMessage(question)]})["messages"][-1].content
#      21
#      22
#      23 # Grades question (uses get_my_grades):
# ---> 24 print(ask("How did I do in Discrete Math in Winter 2024? Which quiz was weakest?"))
#
# Cell In[2], line 20, in ask(question)
#      19 def ask(question):
# ---> 20     return agent.invoke({"messages": [HumanMessage(question)]})["messages"][-1].content
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain\agents\factory.py:1447, in create_agent.<locals>.model_node(state, runtime)
#    1435 request = ModelRequest(
#    1436     model=model,
#    1437     tools=default_tools,
#    (...)   1443     runtime=runtime,
#    1444 )
#    1446 if wrap_model_call_handler is None:
# -> 1447     model_response = _execute_model_sync(request)
#    1448     return _build_commands(model_response)
#    1450 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain\agents\factory.py:1419, in create_agent.<locals>._execute_model_sync(request)
#    1416 if request.system_message:
#    1417     messages = [request.system_message, *messages]
# -> 1419 output = model_.invoke(messages)
#    1420 if name:
#    1421     output.name = name
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_core\runnables\base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1863, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1861 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1862 try:
# -> 1863     data = self._create(payload)
#    1864 except anthropic.BadRequestError as e:
#    1865     _handle_anthropic_bad_request(e)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1495, in ChatAnthropic._create(self, payload)
#    1493 if "betas" in payload:
#    1494     return self._client.beta.messages.create(**payload)
# -> 1495 return self._client.messages.create(**payload)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1135 try:
#    1136     if chain is None:
# -> 1137         response, prepared = self._attempt_request(
#    1138             model_copy(input_options), stream=stream, retries_taken=retries_taken
#    1139         )
#    1140         if response.is_success:
#    1141             return self._process_response(
#    1142                 cast_to=cast_to,
#    1143                 options=prepared,
#    (...)   1147                 retries_taken=retries_taken,
#    1148             )
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_base_client.py:1282, in SyncAPIClient._attempt_request(self, options, stream, retries_taken)
#    1272 """Prepare, build and send a single HTTP attempt.
#    1273
#    1274 Returns the response regardless of its status code, along with the prepared
#    (...)   1278 `APIConnectionError`).
#    1279 """
#    1280 options = self._prepare_options(options)
# -> 1282 request = self._build_request(options, retries_taken=retries_taken)
#    1283 self._prepare_request(request)
#    1285 kwargs: HttpxSendArgs = {}
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_base_client.py:539, in BaseClient._build_request(self, options, retries_taken)
#     536     else:
#     537         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 539 headers = self._build_headers(options, retries_taken=retries_taken)
#     540 params = _merge_mappings(self.default_query, options.params)
#     541 content_type = headers.get("Content-Type")
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_base_client.py:469, in BaseClient._build_headers(self, options, retries_taken)
#     459 merged_headers = merge_headers(
#     460     {
#     461         "x-stainless-timeout": str(options.timeout.read)
#    (...)    466     custom_headers,
#     467 )
#     468 headers_dict = _strip_omit(merged_headers)
# --> 469 self._validate_headers(headers_dict, custom_headers)
#     471 # headers are case-insensitive while dictionaries are not.
#     472 headers = httpx.Headers(headers_dict)
#
# File c:\Users\halah\Downloads\portal-app\.venv\Lib\site-packages\anthropic\_client.py:392, in Anthropic._validate_headers(self, headers, custom_headers)
#     389 if headers.get("Authorization") or isinstance(custom_headers.get("Authorization"), Omit):
#     390     return
# --> 392 raise TypeError(
#     393     '"Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     394 )
#
# TypeError: "Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
# During task with name 'model' and id '25521134-d773-1e10-ac46-7a8f51c9c1d2'

# %% [markdown]
# ## What just happened, and your turn
#
# The agent picked the right tool for each question: `get_my_grades` for the quiz
# marks, `get_my_transcript` for the GPA and year. You asked in plain words
# ("Winter 2024", "2024-2025") and the tools resolved those to the portal's ids.
#
# Your turn:
#
# - Ask it to compare two terms.
# - Add a `my_weakest_courses` tool that scans a transcript year for the lowest grades.
# - Set `GUC_SITE=giu` in `.env` to point the same tools at GIU (once you have a login).
